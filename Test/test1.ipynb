# %%
import mlflow
print("printing mlflow tracking uri:")
print(mlflow.get_tracking_uri())
print("\n")

mlflow.set_tracking_uri("http://127.0.0.1:5000")
print("printing updated mlflow tracking uri:")
print(mlflow.get_tracking_uri())
print("\n")
# Out:
# printing mlflow tracking uri:
# sqlite:///mlflow.db
#
#
# printing updated mlflow tracking uri:
# http://127.0.0.1:5000
